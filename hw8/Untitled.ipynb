# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from yellowbrick.text import TSNEVisualizer
from yellowbrick.text import UMAPVisualizer


data = pd.DataFrame()
data1 = pd.read_csv('Obesity.csv')
data1['label'] = data1['Title'].map(lambda x : 'Obesity' if x is not None else 'Obesity')
data1['text'] = data1['Title']+ data1['Abstract']

data2 = pd.read_csv('Cancer.csv')
data2['label'] = data2['Title'].map(lambda x : 'Cancer' if x is not None else 'Cancer')
data2['text'] = data2['Title']+ data2['Abstract']

data = data.append(data1,ignore_index = True)
data = data.append(data2,ignore_index = True)
data
# Out:
#      Unnamed: 0                                              Title  \
# 0             1  Primary Obesity Surgery Endoluminal (POSE-2) F...
# 1             2  Predictors of laboratory-positive COVID-19 in ...
# 2             3  Direct oral anticoagulants in the treatment of...
# 3             4  Farnesol induces mitochondrial/peroxisomal bio...
# 4             5  &quot;A LEAP 2 Conclusions?: Targeting the Ghr...
# ..          ...                                                ...
# 191          96  A case report of androgen receptor inhibitor t...
# 192          97  Evaluating Six Commercially Available Closed-S...
# 193          98  Auto-antibodies against apolipoprotein A-1 blo...
# 194          99  Evidence for context-dependent functions of KD...
# 195         100  Role of Exosomes in the Progression, Diagnosis...
#
#                                               Abstract    label  \
# 0    Introduction POSE-2 procedure shortens and nar...  Obesity
# ...

# %%
tfidf = TfidfVectorizer()

X = tfidf.fit_transform(data['text'].values.astype('U'))
Y = data['label']

# Create the visualizer and draw the vectors
tsne = TSNEVisualizer()
tsne.fit(X, Y)
tsne.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
umap = UMAPVisualizer()
umap.fit(X, Y)
umap.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA

ipca = IncrementalPCA(n_components=1)
ipca.fit(X)
IncrementalPCA(n_components=1)
ipca.transform(X)
# Out:
# array([[-7.30326456e-02],
#        [-8.35350286e-02],
#        [-6.88125693e-02],
#        [-4.33929763e-02],
#        [-5.01752557e-02],
#        [-5.87515132e-02],
#        [-5.11211424e-02],
#        [-6.49216408e-02],
#        [-2.28592903e-02],
#        [-5.52861188e-02],
#        [-3.91566069e-02],
#        [-4.84752982e-02],
#        [-7.00086844e-02],
#        [-8.84256441e-02],
#        [-8.87333008e-02],
#        [-8.32690343e-02],
#        [-3.30146617e-02],
#        [-4.57269935e-02],
#        [-1.60230072e-02],
#        [-4.59280148e-02],
#        [-3.71031432e-02],
#        [-6.37398857e-02],
#        [-4.09840739e-02],
#        [-4.13847273e-02],
#        [-5.86682777e-02],
#        [-7.47980759e-02],
#        [-4.43817186e-02],
#        [-6.86157665e-02],
#        [-2.87743173e-02],
#        [-4.48741583e-02],
#        [-5.16058175e-02],
#        [-2.34466666e-02],
#        [-4.99951226e-02],
#        [-7.94667740e-02],
#        [-5.61174950e-02],
# ...
